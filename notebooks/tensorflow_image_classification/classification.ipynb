# %%
# based on https://raw.githubusercontent.com/tensorflow/models/master/tutorials/image/imagenet/classify_image.py
# data stored in /tmp/imagenet
from inception import *
# %matplotlib inline
setup()

# %%
download_show_and_run('https://i.ytimg.com/vi/cNycdfFEgBc/maxresdefault.jpg', 'cat-cu.jpg')

# %%
download_show_and_run('https://i.ytimg.com/vi/2Hva7kH8DEo/maxresdefault.jpg', 'axe.jpg')

# %%
download_show_and_run('https://media.timeout.com/images/100914189/image.jpg', 'ice-cream.jpg')

# %%
download_show_and_run('https://upload.wikimedia.org/wikipedia/commons/thumb/3/3e/Tennis_Racket_and_Balls.jpg/220px-Tennis_Racket_and_Balls.jpg', 'tennis')

# %%
download_show_and_run('http://images.boats.com/resize/1/72/41/6077241_20170120112356443_1_LARGE.jpg', 'boat.jpg')

# %%
download_show_and_run('https://p-airnz.com/cms/assets/Common-Assets/Destination-Images/pi-rar-beach-view-2100x822__ScaleWidthWyI5MzAiXQ.jpg', 'beach.jpg')
